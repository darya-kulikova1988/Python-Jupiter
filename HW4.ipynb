# %% [markdown]
# <a href="https://colab.research.google.com/github/darya-kulikova1988/Python-Jupiter/blob/main/HW4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Урок 4. Визуальный анализ данных

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# ##Задача 1
# ######Постройте график, Назовите график, Сделайте именование оси x и оси y
# ######Сделайте выводы

# %%
plt.figure(figsize=(5,4))

plt.hist(df['price'])
plt.title('The cost of houses')
plt.xlabel('Price')
plt.ylabel('Qty');

#1.2 Изучите стоимости недвижимости
#Вывод: наибольшее количество домов продается до 1млн

# %%
#1.3 Изучите распределение квадратуры жилой
plt.figure(figsize=(5,4))

plt.hist(df['sqft_living'])
plt.title('sqft_living of houses')
plt.xlabel('sqft_living')
plt.ylabel('Qty');

# %%
#1.4 Изучите распределение года постройки
plt.figure(figsize=(5,4))

plt.hist(df['yr_built'])
plt.title('yr_built of houses')
plt.xlabel('yr_built')
plt.ylabel('Qty');

# %% [markdown]
# ##2 задача

# %%
#2.1 Изучите распределение домов от наличия вида на набережную

data= df['waterfront'].value_counts()
names=data.index
values=data.values
data
# Out:
# 0    21450
# 1      163
# Name: waterfront, dtype: int64

# %%
plt.figure(figsize=(5,4))
plt.pie(values,autopct='%.1f%%')
plt.title('Распределение домов от наличия вида на набережную')
plt.legend(data.index);

#Менее 1% домов с видом на набережную

# %%
#2.2 Изучите распределение этажей домов

plt.figure(figsize=(5,4))

plt.hist(df['floors'])
plt.title('Распределение домов от кол-ва этажей')
plt.xlabel('floors')
plt.ylabel('Qty');

# %%
data= df['floors'].value_counts()
names=data.index
values=data.values
data

plt.figure(figsize=(5,4))
plt.pie(values,autopct='%.1f%%', labels=names)
plt.title('Распределение домов от кол-ва этажей');
#plt.legend(data.index);

#Самые популярные дома с 1 и 2 этажами, вместе составляют 87,5%

# %%
#2.3 Изучите распределение состояния домов
data= df['condition'].value_counts()
names=data.index
values=data.values
data

plt.figure(figsize=(5,4))
plt.pie(values,autopct='%.1f%%')
plt.title('Распределение домов по состоянию')
plt.legend(data.index);

#Наибольшее количетсво домов с состоянием 3 - 64,9%

# %% [markdown]
# #Задача3

# %%
#Матрица корреляций
import seaborn as sns
corr_matrix=df.corr()

plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',fmt='.1f');
# Out:
# <ipython-input-63-916d256f483c>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix=df.corr()
